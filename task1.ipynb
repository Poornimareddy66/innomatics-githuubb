# %%
USERNAME = "poori"
PASSWORD = "1632"

# %%
input_user = input("Username: ").strip()
input_password = input("Password: ").strip()
# Out:
# Username:  poori
# Password:  1632

# %%
 if input_user == USERNAME and input_password == PASSWORD:
        print("Login Successful")
 else:
        print("Invalid Credentials")
# Out:
# Login Successful

# %%
marks = [45, 78, 90, 33, 60]


PassStud = []
FailStud = []

# %%
for i in marks:
    if i >= 50:
        PassStud.append(i)
    else:
        FailStud.append(i)

# %%
print(PassStud)
print(FailStud)
# Out:
# [78, 90, 60]
# [45, 33]

# %%
messages = ["Hi", "Welcome to the platform", "OK"]

for i in messages:
    print(i, ":", len(i))
# Out:
# Hi : 2
# Welcome to the platform : 23
# OK : 2

# %%
names = [" Alibaba ", "ballaya", " Chandramukhi "]
new_names = [x.strip().lower() for x in names]

print(new_names)
# Out:
# ['alibaba', 'ballaya', 'chandramukhi']

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error_count = logs.count("ERROR")

print("Total error count:" ,  error_count)
# Out:
# Total error count: 2
